# %% [markdown]
# ##WMP Bloodfeed Efficiency Analysis: Summary and Scope

# %% [markdown]
# ##Dataset Overview

# %% [markdown]
# ##Key Findings and Intepretation

# %% [markdown]
# ##Visual Evidence

# %% [markdown]
# ##Limitations

# %% [markdown]
# ##Recommendations

# %% [markdown]
# ##Final Summary
